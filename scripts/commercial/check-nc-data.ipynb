# %%
import pandas as pd

# %%
df = pd.read_csv('archive-cc-2014-nc.csv.gz', nrows=1000)
df
# Out:
#                                             archive_id  \
# 0                    CNNW_20110513_133540_CNN_Newsroom
# 1    CNNW_20110518_223642_The_Situation_Room_With_W...
# 2                   CNNW_20110525_230000_John_King_USA
# 3                    CNNW_20110526_000000_In_the_Arena
# 4            CNNW_20110526_010000_Piers_Morgan_Tonight
# ..                                                 ...
# 995           CNNW_20111207_010000_Anderson_Cooper_360
# 996          CNNW_20111207_020000_Piers_Morgan_Tonight
# 997           CNNW_20111207_030000_Anderson_Cooper_360
# 998         CNNW_20111207_040000_Erin_Burnett_OutFront
# 999          CNNW_20111207_050000_Piers_Morgan_Tonight
#
#                                                text_nc
# 0    been fascinate for me is how much he has a loy...
# 1    a deal to secure the release of dominique stra...
# 2    england, to the queen. >> reporter: one critic...
# 3    tonight we have some amazing pictures to show ...
# 4    the verge of being indicted? i'll ask legal ea...
# ..                                                 ...
# 995  threatening to dredge it up. gingrich reporter...
# 996  the always controversial michael moore for the...
# 997  look at -- look at a spiritual side of what ca...
# 998  shaking my booty ♪ ♪ cutie pa-tootie >> i've w...
# 999  >> i read her book on a plane. bought her book...
#
# [1000 rows x 2 columns]

# %%
df = pd.read_csv('archive-cc-2017-nc.csv.gz', nrows=1000)
df
# Out:
#                                             archive_id  \
# 0                CNNW_20170408_110000_New_Day_Saturday
# 1               FOXNEWSW_20170224_160000_Happening_Now
# 2             FOXNEWSW_20150206_110000_FOX_and_Friends
# 3                  CNNW_20141026_120000_New_Day_Sunday
# 4                 MSNBCW_20120726_050000_The_Last_Word
# ..                                                 ...
# 995      MSNBCW_20161228_090000_The_Rachel_Maddow_Show
# 996   FOXNEWSW_20150625_190000_Shepard_Smith_Reporting
# 997  MSNBCW_20170930_060000_The_11th_Hour_With_Bria...
# 998             FOXNEWSW_20160129_180000_Happening_Now
# 999                   FOXNEWSW_20160417_060000_Red_Eye
#
#                                                text_nc
# 0    the way our founding fathers intended. >> it w...
# 1    building them in this country, not another cou...
# 2    arget should. >> maybe we will if they don't. ...
# 3    kosik in for christi paul. >> i'm victor black...
# 4    >> andrea mitchell is a hard news lady. she ha...
# ..                                                 ...
# 995  the rachel maddow show starts maybe you're luc...
# 996  11:00 a.m. at the nixon library in yorba linda...
# 997  it's day 253 of the trump administration and t...
# 998  they need to teach cursive. anybody knows anyb...
# 999  band that will be performing at the internatio...
#
# [1000 rows x 2 columns]

# %%
df.iloc[1].text_nc.find('clap')
# Out:
# -1

# %%
df = pd.read_csv('archive-cc-2022-nc.csv.gz', nrows=1000)
df
# Out:
#                                             archive_id  \
# 0               CNNW_20190929_090000_CNN_Newsroom_Live
# 1    CNNW_20220203_105900_New_Day_With_John_Berman_...
# 2    FOXNEWSW_20220109_060000_Unfiltered_with_Dan_B...
# 3                    MSNBCW_20200528_170000_MSNBC_Live
# 4    MSNBCW_20201109_030000_American_Voices_With_Al...
# ..                                                 ...
# 995  CNNW_20190820_210000_Situation_Room_With_Wolf_...
# 996  FOXNEWSW_20181222_200000_The_Journal_Editorial...
# 997  CNNW_20200507_190000_CNN_Newsroom_With_Brooke_...
# 998  MSNBCW_20180620_030000_The_11th_Hour_With_Bria...
# 999  CNNW_20200522_130000_CNN_Newsroom_With_Poppy_H...
#
#                                                text_nc
# 0    you're watching cnn "newsroom". still ahead fo...
# 1    he will join us on his explosive lawsuit.   fo...
# 2    is. for the team. high school basketball coach...
# 3    want to exacerbate that. so they are going to ...
# 4    ♪   i'm joshua johnson. good to be with you to...
# ..                                                 ...
# 995  cnn's multiple requests for comment. but does ...
# 996  >> welcome to the journal editorial report. i ...
# 997  you are watching cnn, i'm brooke baldwin. than...
# 998  >> deacon palacios gets tonight's last word. "...
# 999  cohen with more on these new details. we alrea...
#
# [1000 rows x 2 columns]

# %%
df = pd.read_csv('archive-cc-2023-nc.csv.gz', nrows=1000)
df
# Out:
#                                             archive_id  \
# 0                      MSNBCW_20221029_070000_Dateline
# 1    CNNW_20230418_090000_Early_Start_With_Christin...
# 2           CNNW_20230504_230000_Erin_Burnett_OutFront
# 3          MSNBCW_20221228_210000_Deadline_White_House
# 4                MSNBCW_20230402_210000_PoliticsNation
# ..                                                 ...
# 995        FOXNEWSW_20230119_100000_FOX__Friends_First
# 996        FOXNEWSW_20230116_100000_FOX__Friends_First
# 997  MSNBCW_20230206_000000_American_Voices_With_Al...
# 998          FOXNEWSW_20230502_050000_Fox_News_Tonight
# 999  CNNW_20230325_160000_CNN_Newsroom_With_Fredric...
#
#                                                text_nc
# 0    >> she was a young actress starring in the rol...
# 1    issued a warrant for his arrest in missouri. c...
# 2    but a source told cnn he will amend his filing...
# 3    really was. from this latest discovery we have...
# 4    mar-a-lago tuesday night after his court appea...
# ..                                                 ...
# 995  >> carley: a fox news alert, number keeps goin...
# 996  >> carley: the los angeles police department b...
# 997  agenda for the next two years. and the case th...
# 998  is clear to the democratic party. doesn't want...
# 999  many people counting their blessings like the ...
#
# [1000 rows x 2 columns]

# %%
df = pd.read_csv('../shared/archive-cc-2023-all-nc.csv.gz', usecols=['text_nc'])
df
# Out:
#       text_nc
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 32995     NaN
# 32996     NaN
# 32997     NaN
# 32998     NaN
# 32999     NaN
#
# [33000 rows x 1 columns]

# %%
df[df.text_nc.notnull()]
# Out:
#                                                  text_nc
# 63     story" of thursday, june 1, 2023. now the stor...
# 88     >> john: he does appear to be fine. thanks for...
# 92     >> neil: i recommend the 100-foot rope climb i...
# 94     but now there's news of this damning tape that...
# 524    >> greg: we are out of time. thanks to dana pe...
# ...                                                  ...
# 32447  angle. now, people on the coast can't be this ...
# 32713  florida state prison. >> reporter: after tony ...
# 32744  united states and around the world. i'm fareed...
# 32745  penicillin, it's 20 deaths per million users. ...
# 32789  kentucky zoo last weekend knocked on the glass...
#
# [1719 rows x 1 columns]

# %%
df = pd.read_csv('../shared/archive-cc-2017-all-nc.csv.gz')
df
# Out:
#      DESCRIPTION  PROGRAM  access-restricted  addeddate aspect_ratio  \
# 0            NaN      NaN                NaN        NaN          4:3
# 1            NaN      NaN                NaN        NaN          4:3
# 2            NaN      NaN                NaN        NaN         16:9
# 3            NaN      NaN                NaN        NaN         16:9
# 4            NaN      NaN                NaN        NaN          4:3
# ..           ...      ...                ...        ...          ...
# 195          NaN      NaN                NaN        NaN          4:3
# 196          NaN      NaN                NaN        NaN         16:9
# 197          NaN      NaN                NaN        NaN          4:3
# 198          NaN      NaN                NaN        NaN          4:3
# 199          NaN      NaN                NaN        NaN          4:3
#
#     audio_codec  audio_sample_rate backup_location ccnum closed_captioning  \
# 0           ac3            48000.0     ia905909_22     0                no
# 1           ac3            48000.0     ia903705_33   cc5               yes
# 2           ac3            48000.0      ia905708_2   cc5               yes
# 3           ac3            48000.0      ia905808_9   cc5               yes
# 4           ac3            48000.0     ia903708_22   cc5               yes
# ..          ...                ...             ...   ...               ...
# 195         ac3            48000.0      ia905503_5   cc5               yes
# 196         mp2            48000.0      ia905707_4     0                no
# 197         ac3            48000.0             NaN     0                no
# 198         ac3            48000.0             NaN     0                no
# 199         ac3            48000.0     ia903904_34   cc5                no
#
#      ...                                              title  \
# 0    ...  Journal News/Germany Today : KMTP : January 13...
# 1    ...  U.S. House of Representatives : CSPAN : Novemb...
# 2    ...  Countdown to the Closing Bell : FBC : October ...
# 3    ...  In the Loop With Betty Liu : BLOOMBERG : May 2...
# 4    ...  CBS 5 Eyewitness News at 6PM : KPIX : February...
# ..   ...                                                ...
# 195  ...  Washington Journal : CSPAN : October 6, 2015 7...
# 196  ...  Headline News : RT : September 17, 2013 7:00am...
# 197  ...  News from Taiwan : KCNS : November 5, 2016 7:0...
# 198  ...  News from Taiwan : KCNS : June 30, 2017 8:30am...
# 199  ...  Al Jazeera World News : LINKTV : July 26, 2012...
#
#                      tuner  updatedate updater        uploader  utc_offset  \
# 0              Channel v32         NaN     NaN  tv@archive.org      -800.0
# 1    Channel 100 (651 MHz)         NaN     NaN  tv@archive.org      -500.0
# 2             Channel v761         NaN     NaN  tv@archive.org      -400.0
# 3             Channel v821         NaN     NaN  tv@archive.org      -400.0
# 4     Channel 93 (639 MHz)         NaN     NaN  tv@archive.org      -800.0
# ..                     ...         ...     ...             ...         ...
# 195            Channel v24         NaN     NaN  tv@archive.org      -400.0
# 196           Channel 1402         NaN     NaN  tv@archive.org      -700.0
# 197        Virtual Ch. 172         NaN     NaN  tv@archive.org      -700.0
# 198        Virtual Ch. 172         NaN     NaN  tv@archive.org      -700.0
# 199   Channel 89 (615 MHz)         NaN     NaN  tv@archive.org      -700.0
#
#      utm_term video_codec    year  text_nc
# 0         NaN  mpeg2video  2015.0      NaN
# 1         NaN  mpeg2video  2011.0      NaN
# 2         NaN  mpeg2video  2013.0      NaN
# 3         NaN  mpeg2video  2014.0      NaN
# 4         NaN  mpeg2video  2012.0      NaN
# ..        ...         ...     ...      ...
# 195       NaN  mpeg2video  2015.0      NaN
# 196       NaN  mpeg2video  2013.0      NaN
# 197       NaN  mpeg2video  2016.0      NaN
# 198       NaN  mpeg2video  2017.0      NaN
# 199       NaN  mpeg2video  2012.0      NaN
#
# [200 rows x 83 columns]

# %%
df[df.text_nc.notnull()][['text', 'text_nc']]
# Out:
#                                                   text  \
# 11   medication every day at 4:00 a.m. >> i do love...
# 18   good night. >> this is not just cold blood a k...
# 31   thank you for watching. have a wonderful weeke...
# 42   [ cheers and applause ] >> thank you very much...
# 59   us at fox now doot com. be sure to follow us o...
# 72   this right. and you can have me on for a secon...
# 75   mcdonald. i recommend that they look someplace...
# 85   great that first time. aside from punking neo-...
# 97   what i've done is just about the stupid eest t...
# 108  >> there you go. julie pace. >> >> i learned t...
# 115  u.k. >> you want the red carpet clean. you rea...
# 121  i'm martin savidge. the next hour of the cnn n...
# 130  could have turned the alleged vandal into an a...
# 131  >> shep: this is fox report. right now the pol...
# 135  as much as it saddens me, that wraps up this h...
# 139  of the alabama and mississippi primaries, not ...
# 146  cut. not long after that she lost her job. tod...
# 155  overestimated. >> a very compelling argument a...
# 158  we have breaking news in the alabama hostage r...
# 162  into campaign mode in july or august. >> luke ...
# 170  in the united states and around the world. you...
# 172  and it's not over. that does it for us tonight...
# 177  a retired u.s. military personnel, barbara sta...
# 185  their kids, too. best of luck and keep in touc...
# 193  çuéxwxoñçñwelcome back to our two-hour speci...
#
#                                                text_nc
# 11   medication every day at 4:00 a.m. >> i do love...
# 18   good night. >> this is not just cold blood a k...
# 31   thank you for watching. have a wonderful weeke...
# 42   oil is gushing from the container tank rena wh...
# 59   us at fox now doot com. be sure to follow us o...
# 72   this right. and you can have me on for a secon...
# 75   >> the fight was about defunding obama care. >...
# 85   this is "the ed show." let's get to work. >> i...
# 97   as governor of california. and what does ar na...
# 108  >> there you go. julie pace. >> >> i learned t...
# 115  u.k. >> you want the red carpet clean. you rea...
# 121  i'm martin savidge. the next hour of the cnn n...
# 130  could have turned the alleged vandal into an a...
# 131  >> shep: this is fox report. right now the pol...
# 135  reach across the aisle? even the president say...
# 139  you see 22 body bags in all of the 45 who were...
# 146  cut. not long after that she lost her job. tod...
# 155  overestimated. >> a very compelling argument a...
# 158  bunker for nearly a week now, talking with aut...
# 162  into campaign mode in july or august. >> luke ...
# 170  in the united states and around the world. you...
# 172  >> how are you? great to see you. >> the bigge...
# 177  a retired u.s. military personnel, barbara sta...
# 185  their kids, too. best of luck and keep in touc...
# 193  welcome back to our two-hour special coverage,...

# %%
df = pd.read_csv('../shared/archive-cc-2014-all-nc.csv.gz', nrows=3000)
df
# Out:
#      aspect_ratio audio_codec  audio_sample_rate  caption_change  ccnum  \
# 0             4:3         ac3              48000             NaN      5
# 1             4:3         ac3              48000             NaN      5
# 2             4:3         ac3              48000             NaN      5
# 3             4:3         ac3              48000             NaN      5
# 4             4:3         ac3              48000             NaN      5
# ...           ...         ...                ...             ...    ...
# 2995          4:3         ac3              48000             NaN      5
# 2996          4:3         ac3              48000             NaN      5
# 2997          4:3         ac3              48000             NaN      5
# 2998          4:3         ac3              48000             NaN      5
# 2999          4:3         ac3              48000             NaN      5
#
#      closed_captioning                  collection  color contributor  \
# 0                  yes   TV-CSPAN|tvarchive|tvnews  color       CSPAN
# 1                  yes   TV-CSPAN|tvarchive|tvnews  color       CSPAN
# 2                  yes   TV-CSPAN|tvarchive|tvnews  color       CSPAN
# 3                  yes  TV-CSPAN2|tvarchive|tvnews  color      CSPAN2
# 4                  yes  TV-CSPAN2|tvarchive|tvnews  color      CSPAN2
# ...                ...                         ...    ...         ...
# 2995               yes  TV-CSPAN2|tvarchive|tvnews  color      CSPAN2
# 2996               yes    TV-WHUT|tvarchive|tvnews  color        WHUT
# 2997               yes    TV-WMAR|tvarchive|tvnews  color        WMAR
# 2998               yes    TV-WJLA|tvarchive|tvnews  color        WJLA
# 2999               yes    TV-WMAR|tvarchive|tvnews  color        WMAR
#
#                                                curation  ...  \
# 0     [curator]tracey@archive.org[/curator][date]201...  ...
# 1     [curator]tracey@archive.org[/curator][date]201...  ...
# 2     [curator]tracey@archive.org[/curator][date]201...  ...
# 3     [curator]tracey@archive.org[/curator][date]201...  ...
# 4     [curator]tracey@archive.org[/curator][date]201...  ...
# ...                                                 ...  ...
# 2995                                                NaN  ...
# 2996                                                NaN  ...
# 2997                                                NaN  ...
# 2998                                                NaN  ...
# 2999                                                NaN  ...
#
#                                                    text  \
# 0     record -- the chair: the gentlelady has to mak...
# 1     they can issue waivers to applicants when they...
# 2     republicans again refused to bring the legisla...
# 3     florida, the oldest continuous settlement in t...
# 4     >> since ten minutes has come to an end i will...
# ...                                                 ...
# 2995  political genius of an american icon. .. , was...
# 2996  >> abernethy: coming up, an eye clinic where, ...
# 2997  welcome welcome to "world news." tonight, brea...
# 2998  "good morning america." the battle begins over...
# 2999  this morning" continues after this.   sweet! s...
#
#                                                   title  tuner  updatedate  \
# 0     [curator: unknown title] : CSPAN : June 4, 200...    NaN         NaN
# 1     [curator: unknown title] : CSPAN : June 4, 200...    NaN         NaN
# 2     [curator: unknown title] : CSPAN : June 4, 200...    NaN         NaN
# 3     [curator: unknown title] : CSPAN2 : June 4, 20...    NaN         NaN
# 4     [curator: unknown title] : CSPAN2 : June 4, 20...    NaN         NaN
# ...                                                 ...    ...         ...
# 2995  In Depth : CSPAN2 : July 6, 2009 12:00am-3:00a...    NaN         NaN
# 2996  Religion\n&\nEthics Newsweekly : WHUT : July 5...    NaN         NaN
# 2997  ABC's World News With Charles Gibson : WMAR : ...    NaN         NaN
# 2998  ABC News Good Morning America : WJLA : July 6,...    NaN         NaN
# 2999  ABC2 News Good Morning Maryland 5AM : WMAR : J...    NaN         NaN
#
#      updater        uploader  utc_offset video_codec  year  text_nc
# 0        NaN  tv@archive.org        -400  mpeg2video  2009      NaN
# 1        NaN  tv@archive.org        -400  mpeg2video  2009      NaN
# 2        NaN  tv@archive.org        -400  mpeg2video  2009      NaN
# 3        NaN  tv@archive.org        -400  mpeg2video  2009      NaN
# 4        NaN  tv@archive.org        -400  mpeg2video  2009      NaN
# ...      ...             ...         ...         ...   ...      ...
# 2995     NaN  tv@archive.org        -400  mpeg2video  2009      NaN
# 2996     NaN  tv@archive.org        -400  mpeg2video  2009      NaN
# 2997     NaN  tv@archive.org        -400  mpeg2video  2009      NaN
# 2998     NaN  tv@archive.org        -400  mpeg2video  2009      NaN
# 2999     NaN  tv@archive.org        -400  mpeg2video  2009      NaN
#
# [3000 rows x 50 columns]

# %%
df[df.text_nc.notnull()][['text', 'text_nc']]
# Out:
#                                                    text  \
# 2448  jackson's family iss waiting to hear resultsff...
# 2503  -- it gives new meaning it to an ice-cream hae...
# 2504  seeing, i just what we have seen in the last f...
# 2509  it everythg morning. >> i'm monica novotny. >>...
# 2512  > michaeljackson's last dance. neww footage f ...
# ...                                                 ...
# 2899  many others. lots of insights. remember, can y...
# 2909  ♪ never can say good-bye, no, no, no, no, i ne...
# 2920  mistake, telling t associated press in 1995, q...
# 2923  >> larry: we've been at the neverland ranch. w...
# 2994  lin has probably srr from time totime. will le...
#
#                                                 text_nc
# 2448  jackson's family iss waiting to hear resultsff...
# 2503  -- it gives new meaning it to an ice-cream hae...
# 2504  seeing, i just what we have seen in the last f...
# 2509  it everythg morning. >> i'm monica novotny. >>...
# 2512  > michaeljackson's last dance. neww footage f ...
# ...                                                 ...
# 2899  many others. lots of insights. remember, can y...
# 2909  rehearsals caught on tape. you're looking at m...
# 2920  mistake, telling t associated press in 1995, q...
# 2923  >> larry: we've been at the neverland ranch. w...
# 2994  lin has probably srr from time totime. will le...
#
# [92 rows x 2 columns]
