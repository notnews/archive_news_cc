# %%
#!pip install "pyDataverse<0.3.0"

# %%
# Dataverse API Token
# https://dataverse.harvard.edu/dataverseuser.xhtml?selectTab=apiTokenTab
host = 'https://dataverse.harvard.edu'
token = ''
doi = 'doi:10.7910/DVN/OAJJHI'

# %%
from pyDataverse.api import Api

# %%
api = Api('https://dataverse.harvard.edu/', token)
api.status

# %%
resp = api.get_dataset(doi)
resp.json()

# %% [markdown]
# ### CSV file year 2023

# %%
from glob import glob

for fn in sorted(glob('./archive_news_cc/archive-cc-2023.csv.gz*')):
    print(fn)
    resp = api.upload_file(doi, fn)
    print(resp)

# %% [markdown]
# ### Search identifiers CSV file year 2023

# %%
for fn in sorted(glob('./archive_news_cc/data/search-2023.csv')):
    print(fn)
    resp = api.upload_file(doi, fn)
    print(resp)

# %% [markdown]
# ### Meta file year 2023

# %%
for fn in sorted(glob('./archive_news_cc/data/meta-2023.tar.gz*')):
    print(fn)
    resp = api.upload_file(doi, fn)
    print(resp)

# %% [markdown]
# ### HTML file year 2023

# %%
for fn in sorted(glob('./archive_news_cc/data/html-2023.tar.gza*')):
    print(fn)
    resp = api.upload_file(doi, fn)
    print(resp)
